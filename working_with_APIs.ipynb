# %% [markdown]
# <a href="https://colab.research.google.com/github/AsifBrohi/Working_with_APIs/blob/main/working_with_APIs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import requests
import time

# %%
API_KEY= "AIzaSyBqK2Q3yv3ZSbZiqdsQkLuaRi7ijRhZNE4"
CHANNEL_ID = "UCOMwQZ90G20Hv3MmTHjewBA"

# %%
def get_video_details(video_id):


    url_video_stats= "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
    response_video_stats=requests.get(url_video_stats).json()

    like_count=response_video_stats['items'][0]['statistics']['likeCount']
    view_count=response_video_stats['items'][0]['statistics']['viewCount']
    comment_count=response_video_stats['items'][0]['statistics']['commentCount']
    
    return like_count,view_count,comment_count

# %%
def get_videos(df):

    pageToken=""
    url= "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=1000"+pageToken
    response=requests.get(url).json()
    time.sleep(1)

    for video in response['items']:
      if video['id']['kind']== 'youtube#video':
          video_id=video['id']['videoId']
          video_title=video['snippet']['title']
          upload_date=video['snippet']['publishedAt']
          upload_date=str(upload_date).split('T')[0]
   
      like_count,view_count,comment_count= get_video_details(video_id)

    
    
   
      df=df.append({'video_id':video_id,'video_title':video_title,
                  'upload_date':upload_date,'like_count':like_count,
                  'view_count':view_count,'comment_count':comment_count},ignore_index=True)
    return df

# %%
df=pd.DataFrame(columns=['video_id','video_title','upload_date','like_count','view_count','comment_count'])
df=get_videos(df)

# %%
df
# Out:
#        video_id  ... comment_count
# 0   wSfpbxAE3FA  ...           448
# 1   Xp5NlghnzIs  ...           970
# 2   NqXn_U-2cU4  ...           256
# 3   rN6v6LPciIs  ...           117
# 4   LErZxCQTPU0  ...           460
# 5   FUW_7PZ_erw  ...          2359
# 6   nbKPSqzaAGQ  ...           798
# 7   hAqGb7D4xgk  ...           945
# 8   bT6f-C-ZBOY  ...           148
# 9   EWlknWF8wBg  ...           692
# 10  T2WXu2tDWRk  ...            47
# 11  T2WXu2tDWRk  ...            47
# 12  8mOGICCP-c8  ...           166
# 13  vDf8qTikxa0  ...          1118
# 14  QF_RzLu1hpQ  ...           322
# 15  nbO84fqq5BI  ...            21
# 16  x5aICa-ca8M  ...            58
# 17  rte3Zl9FEuU  ...           194
# 18  hNkISY5TVz4  ...            44
# 19  HKgcvIG_XXA  ...             8
# 20  8pJt3kvP954  ...          1287
# 21  gu2J-XWROeA  ...            21
# 22  dgEIUSHgmU4  ...           108
# 23  u5YrSjVekwA  ...           126
# 24  dGdedgTK5ig  ...            21
# 25  a4IXl4V4prg  ...           530
# ...
